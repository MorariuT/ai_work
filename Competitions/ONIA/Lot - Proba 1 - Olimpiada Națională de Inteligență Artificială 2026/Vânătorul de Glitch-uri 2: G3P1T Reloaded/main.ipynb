# %%
import PIL.Image as Image   
import numpy as np

# %%
img1 = Image.open("train/images/img_012.png")

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
mask1 = Image.open("train/masks/img_012.png")

# %%
import matplotlib.pyplot as plt
plt.matshow(np.array(mask1) / 4)
