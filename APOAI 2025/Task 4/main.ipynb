# %%
import pandas as pd

# %%
train = pd.read_csv("pendulum_train.csv")

# %%
train
# Out:
#              t     theta
# 0     0.000000  1.050000
# 1     0.015015  1.049805
# 2     0.030030  1.049222
# 3     0.045045  1.048253
# 4     0.060060  1.046903
# ..         ...       ...
# 729  14.939940 -0.003654
# 730  14.954955 -0.004669
# 731  14.969970 -0.005666
# 732  14.984985 -0.006643
# 733  15.000000 -0.007598
#
# [734 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(train["t"], train["theta"])
