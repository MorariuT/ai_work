# %%
import pandas as pd
import glob

# %%
healthy_data_dir = "./Potato Plant Diseases Data/PotatoPlants/Potato___healthy/";
early_data_dir = "./Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/";
late_data_dir = "./Potato Plant Diseases Data/PotatoPlants/Potato___Late_blight/";

paths_healthy = glob.glob(healthy_data_dir + "*.JPG");
paths_early = glob.glob(early_data_dir + "*.JPG");
paths_late = glob.glob(late_data_dir + "*.JPG");

print(paths_early);
# Out:
# ['./Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/acb84d77-5b1c-4beb-be27-99fee467bf1f___RS_Early.B 7577.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/bc7552e4-3901-41b8-8bef-727eeca4270e___RS_Early.B 7942.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/1994cd3e-4000-4c56-bede-d35a1eecc287___RS_Early.B 6867.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/d8a8d6e5-d82d-4f7c-aac5-183e85549d9b___RS_Early.B 7799.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/1b4304a9-88c2-4c09-bfea-830fa162a35a___RS_Early.B 7188.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/86a65e8c-c7cf-45f7-8619-422eb6f1a40d___RS_Early.B 7745.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/60096f66-1bf2-4d8d-8137-ac2358ab71d0___RS_Early.B 6978.JPG', './Potato Plant Diseases Data/PotatoPlants/Potato___Early_blight/7ba072ea-9bb3-4b5e-8fff-82758ff3f722___RS_Early.B 
# ...

# %%
import numpy as np
images = np.array([]);
labels = np.array([]);

# %%
import PIL
import PIL.Image
import matplotlib.pyplot as plt

plt.style.use("dark_background");

f, ax = plt.subplots(2, 2);

f.set_figwidth(10);
f.set_figheight(10);

it = 0;

for path in paths_healthy:
    img = PIL.Image.open(path);
    img = img.resize((100, 100));

    np.append(images, np.array(img));
    np.append(labels, [1, 0, 0]);

    if(it < 4): 
        ax[it % 2][it // 2].imshow(img);
        ax[it % 2][it // 2].set_title("Frunza sanatoasa " + str(it + 1))

    it += 1;

# %%
f, ax = plt.subplots(2, 2);

f.set_figwidth(10);
f.set_figheight(10);

it = 0;

for path in paths_early:
    img = PIL.Image.open(path);
    img = img.resize((100, 100));
    np.append(images, np.array(img));
    np.append(labels, [1, 0, 0]);
    if(it < 4): 
        ax[it % 2][it // 2].imshow(img);
        ax[it % 2][it // 2].set_title("Frunza bolnava early " + str(it + 1))

    it += 1;

# %%
f, ax = plt.subplots(2, 2);

f.set_figwidth(10);
f.set_figheight(10);

it = 0;

for path in paths_late:
    img = PIL.Image.open(path);
    img = img.resize((100, 100));
    np.append(images, np.array(img));
    np.append(labels, [1, 0, 0]);
    if(it < 4): 
        ax[it % 2][it // 2].imshow(img);
        ax[it % 2][it // 2].set_title("Frunza bolnava late " + str(it + 1))

    it += 1;

# %%
print(images)
# Out:
# []

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(3))

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 model.fit()
#
# File ~/Documents/.venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Documents/.venv/lib/python3.9/site-packages/keras/engine/data_adapter.py:1082, in select_data_adapter(x, y)
#    1079 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1080 if not adapter_cls:
#    1081     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1082     raise ValueError(
# ...
