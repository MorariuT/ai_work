# %%
import numpy as np

# %%
class TudorNet():
    def __init__(self, input_size = 4, output_size = 1, hidden_size = 10):
        input_layer=input_size
        hidden_layer=hidden_size
        output_layer=output_size
        
        self.params = {
            "W1": np.random.randn(hidden_layer, input_layer) * np.sqrt(1./input_layer),
            "W2": np.random.randn(output_layer, hidden_layer) * np.sqrt(1./hidden_layer),
        }

        self.activation = {
            "W1": self.relu,
            "W2": self.sigmoid,
        }

        self.cache = {}
    
    def sigmoid(self, X):
        return (1 / (1 + np.e ** -X))
    
    def sigmoid_derivate(self, X):
        return X * (1 - X);

    def relu(self, X):
        return max(X, 0)
    
    def relu_derivative(self, X):
        if(X <= 0): return 0
        return 1
    
    def mse(self, y_pred, y_true):
        return np.sum((y_pred - y_true) ** 2) / len(y_pred)
    
    def predict(self, X):
        self.cache["X"] = X
        self.cache["Z1"] = np.matmul(self.params["W1"], self.cache["X"].T)
        self.cache["A1"] = self.activation(self.cache["Z1"])
        self.cache["Z2"] = np.matmul(self.params["W2"], self.cache["A1"])
        self.cache["A2"] = self.softmax(self.cache["Z2"])
        return self.cache["A2"]
    
    def back_prop(self, y_true, y_pred):
        current_batch_size = y_true.shape[0]
        
        dZ2 = y_pred - y_true.T
        dW2 = (1./current_batch_size) * np.matmul(dZ2, self.cache["A1"].T)
        dA1 = np.matmul(self.params["W2"].T, dZ2)
        dZ1 = dA1 * self.activation(self.cache["Z1"], derivative=True)
        dW1 = (1./current_batch_size) * np.matmul(dZ1, self.cache["X"])

        grads = {"W1": dW1, "W2": dW2}
        return grads
    
    def train(self, X, y):
        output = self.feed_forward(X)
        g = self.back_propagate(y, output)
        print(g)

# %%
model = TudorNet()

model.predict(np.array([[1, 2]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 model = TudorNet()
# ----> 3 model.predict(np.array([[1, 2]]))
#
# Cell In[14], line 37, in TudorNet.predict(self, X)
#      35 def predict(self, X):
#      36     self.cache["X"] = X
# ---> 37     self.cache["Z1"] = np.matmul(self.params["W1"], self.cache["X"].T)
#      38     self.cache["A1"] = self.activation(self.cache["Z1"])
#      39     self.cache["Z2"] = np.matmul(self.params["W2"], self.cache["A1"])
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 4)
