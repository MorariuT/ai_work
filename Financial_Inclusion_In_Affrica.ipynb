# %%
import pandas as pd

train_data = pd.read_csv("Train.csv")
test_data = pd.read_csv("Test.csv")

# train_data.drop(columns="year", inplace=True)
# test_data.drop(columns="year", inplace=True)

countruies = test_data["country"]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
test_data["country"].unique()
# Out:
# array(['Kenya', 'Rwanda', 'Tanzania', 'Uganda'], dtype=object)

# %%
train_data
# Out:
#       country  year       uniqueid bank_account location_type  \
# 0       Kenya  2018     uniqueid_1          Yes         Rural
# 1       Kenya  2018     uniqueid_2           No         Rural
# 2       Kenya  2018     uniqueid_3          Yes         Urban
# 3       Kenya  2018     uniqueid_4           No         Rural
# 4       Kenya  2018     uniqueid_5           No         Urban
# ...       ...   ...            ...          ...           ...
# 23519  Uganda  2018  uniqueid_2113           No         Rural
# 23520  Uganda  2018  uniqueid_2114           No         Rural
# 23521  Uganda  2018  uniqueid_2115           No         Rural
# 23522  Uganda  2018  uniqueid_2116           No         Urban
# 23523  Uganda  2018  uniqueid_2117           No         Rural
#
#       cellphone_access  household_size  age_of_respondent  \
# 0                  Yes               3                 24
# 1                   No               5                 70
# ...

# %%
train_data.groupby(["country","bank_account"]).count()
# Out:
#                        year  uniqueid  location_type  cellphone_access  \
# country  bank_account
# Kenya    No            4547      4547           4547              4547
#          Yes           1521      1521           1521              1521
# Rwanda   No            7732      7732           7732              7732
#          Yes           1003      1003           1003              1003
# Tanzania No            6013      6013           6013              6013
#          Yes            607       607            607               607
# Uganda   No            1920      1920           1920              1920
#          Yes            181       181            181               181
#
#                        household_size  age_of_respondent  \
# country  bank_account
# Kenya    No                      4547               4547
#          Yes                     1521               1521
# Rwanda   No                      7732               7732
# ...

# %%
# train_data.drop(columns=["cellphone_access", "household_size", "year"], inplace=True)
# test_data.drop(columns=["cellphone_access", "household_size", "year"], inplace=True)

# %%
# # def one_hot_encoding(col, data):
# #     uniq = data[col].unique()   

# #     for val in uniq:
# #         data[col + "_" + str(val)] = data[col].apply(lambda x: int(x == val))
    
# #     return data

# def apply_transform(data):

# #     data = one_hot_encoding("country", data)
# #     data = one_hot_encoding("relationship_with_head", data)
# #     data = one_hot_encoding("marital_status", data)
# #     data = one_hot_encoding("education_level", data)
# #     data = one_hot_encoding("job_type", data)

# #     # data["country"] = data["country"].map({"Kenya": 3, "Rwanda": 2, "Tanzania": 1, "Uganda": 0})
#     if("bank_account" in data.columns): data["bank_account"] = data["bank_account"].map({"No": 0, "Yes": 1})
# #     data["location_type"] = data["location_type"].map({"Rural": 0, "Urban": 1})
# #     data["cellphone_access"] = data["cellphone_access"].map({"No": 0, "Yes": 1})

#     # data["year"] = data["cellphone_access"].map({2016: 3, 
#     #                                              2017: 1,
#     #                                              2018: 7})

#     # data["gender_of_respondent"] = data["gender_of_respondent"].map({"Female": 1, 
#     #                                                                  "Male": 7})



    
#     data["relationship_with_head"] = data["relationship_with_head"].map({"Other non-relatives": 0.3, 
#                                                                          "Other relative": 0.6,
#                                                                          "Child": 0.1,
#                                                                          "Parent": 1.3,
#                                                                          "Spouse": 3,
#                                                                          "Head of Household": 8})
    
#     # data["country"] = data["country"].map({"Uganda": 0, 
#     #                                         "Rwanda": 1.4,
#     #                                         "Tanzania": 2.4,
#     #                                         "Kenya": 4})
    


    
#     data["marital_status"] = data["marital_status"].map({"Dont know": 0, 
#                                                          "Divorced/Seperated": 1.4,
#                                                          "Widowed": 1,
#                                                          "Single/Never Married": 2,
#                                                          "Married/Living together": 5})
    
#     data["education_level"] = data["education_level"].map({"No formal education": 1, 
#                                                            "Other/Dont know/RTA": 0,
#                                                            "Primary education": 2,
#                                                            "Secondary education": 5,
#                                                            "Vocational/Specialised training": 11,
#                                                            "Tertiary education": 12})
    
#     data["job_type"] = data["job_type"].map({"No Income": 0, 
#                                              "Dont Know/Refuse to answer": 0,
#                                              "Other Income": 2,
#                                              "Remittance Dependent": 1,
#                                              "Government Dependent": 2.5,
#                                              "Farming and Fishing": 2,
#                                              "Formally employed Private": 6,
#                                              "Formally employed Government": 10,
#                                              "Self employed": 1.8,
#                                              "Informally employed": 2})

    
    
#     return data

# train_data = apply_transform(train_data)
# test_data = apply_transform(test_data)



# # proc_cols = ["location_type", "relationship_with_head", "marital_status", "education_level", "job_type", "age_of_respondent", "household_size"]

# # train_data.drop(columns=proc_cols, inplace=True)
# # train_data.drop(columns="country", inplace=True)
# # test_data.drop(columns=proc_cols, inplace=True)
# # display(train_data)

# # # for col in proc_cols:

# # #     df_count = train_data.groupby(col).sum()["bank_account"] / train_data.groupby(col).count()["bank_account"]
# # #     map_count = (train_data.groupby(col).sum()["bank_account"] / train_data.groupby(col).count()["bank_account"]).values


# # #     map_new_count = {}

# # #     # df_count.index: map_count


# # #     idx = 0
# # #     for i in df_count.index:
# # #         map_new_count[i] = map_count[idx]
# # #         idx += 1


# # #     train_data[col] = train_data[col].apply(lambda x: map_new_count[x])
# # #     test_data[col] = test_data[col].apply(lambda x: map_new_count[x])

# %%
train_data.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type'],
#       dtype='object')

# %%
train_data.drop(columns="uniqueid", inplace=True)

# %%
# train_data.drop(columns="year", inplace=True)
# test_data.drop(columns="year", inplace=True)

# %%
ids = test_data["uniqueid"]
test_data.drop(columns="uniqueid", inplace=True)

# %%
# train_data.boxplot(figsize=(20, 20))

# %%
# import seaborn as sns

# sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# sns.heatmap(train_data.corr(), vmin=-1.0, vmax=1.0, xticklabels=1, yticklabels=1)

# %% [markdown]
# "Uganda": 0,
# "Rwanda": 1.4,
# "Tanzania": 2.4,
# "Kenya": 4

# %%
train_X = train_data.drop(columns="bank_account")
train_y = train_data["bank_account"].map({"Yes": 1, "No": 0})

# %%
train_X["year"] = train_X["year"].astype(str)
test_data["year"] = test_data["year"].astype(str)

# %%
test_data
# Out:
#       country  year location_type cellphone_access  household_size  \
# 0       Kenya  2018         Urban              Yes               3
# 1       Kenya  2018         Urban              Yes               7
# 2       Kenya  2018         Rural               No               3
# 3       Kenya  2018         Rural               No               6
# 4       Kenya  2018         Urban               No               3
# ...       ...   ...           ...              ...             ...
# 10081  Uganda  2018         Rural               No               2
# 10082  Uganda  2018         Urban              Yes               8
# 10083  Uganda  2018         Urban              Yes               1
# 10084  Uganda  2018         Rural              Yes               6
# 10085  Uganda  2018         Urban              Yes               7
#
#        age_of_respondent gender_of_respondent relationship_with_head  \
# 0                     30                 Male      Head of Household
# ...

# %%
import category_encoders as ce 

cbe = ce.cat_boost.CatBoostEncoder() 
cbe1 = ce.cat_boost.CatBoostEncoder() 

cbe.fit(train_X, train_y) 

cbe1.fit(train_X, train_y) 
train_X = cbe.transform(train_X) 

test_data = cbe1.transform(test_data)

# %%
from sklearn.preprocessing import Normalizer

train_X = Normalizer().fit_transform(train_X)
test_data = Normalizer().fit_transform(test_data)

# %%
# from sklearn.decomposition import PCA
# import matplotlib.pyplot as plt

# points = PCA(n_components=2).fit_transform(train_X)

# plt.scatter(points[:, 0], points[:, 1], c=train_y, alpha=0.2)

# %%
# from sklearn.feature_selection import RFE, RFECV

# selector = RFE(catboost.CatBoostClassifier(), n_features_to_select=5)

# selector.fit(train_X, train_y)

# %%
# selector.get_support()

# %%
# cols = []

# for i, col in enumerate(train_X.columns):
#     if(selector.get_support()[i] == True):
#         cols.append(col)

# train_X = train_X[cols]
# test_data = test_data[cols]

# %%
train_X
# Out:
# array([[0.01036027, 0.00861177, 0.00481572, ..., 0.00717554, 0.00962079,
#         0.00544548],
#        [0.00357141, 0.00296866, 0.00166008, ..., 0.00128416, 0.00055577,
#         0.00288089],
#        [0.00946271, 0.00786569, 0.00674795, ..., 0.0045686 , 0.02151325,
#         0.00497371],
#        ...,
#        [0.00313799, 0.0075865 , 0.00424239, ..., 0.0032817 , 0.00311176,
#         0.00660709],
#        [0.00279706, 0.00676225, 0.00580131, ..., 0.00365896, 0.00755456,
#         0.00427597],
#        [0.00385307, 0.0093153 , 0.00520914, ..., 0.00541057, 0.01040675,
#         0.00093559]])

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

points = PCA(n_components=2).fit_transform(train_X)

plt.scatter(points[:, 0], points[:, 1], marker='.', c=train_y)

# %%
# train_X.dtypes.values

# %%
from sklearn.preprocessing import MinMaxScaler

# def norm(data):
#     for c in data.columns:
#         if(data[c].dtypes != 'O'):
#             data[c] = (MinMaxScaler().fit_transform(data[c].values.reshape(-1, 1)) * 1000).astype(int)

#     return data

# train_X = norm(train_X)
# test_data = norm(test_data)

# %%
train_X
# Out:
# array([[0.01036027, 0.00861177, 0.00481572, ..., 0.00717554, 0.00962079,
#         0.00544548],
#        [0.00357141, 0.00296866, 0.00166008, ..., 0.00128416, 0.00055577,
#         0.00288089],
#        [0.00946271, 0.00786569, 0.00674795, ..., 0.0045686 , 0.02151325,
#         0.00497371],
#        ...,
#        [0.00313799, 0.0075865 , 0.00424239, ..., 0.0032817 , 0.00311176,
#         0.00660709],
#        [0.00279706, 0.00676225, 0.00580131, ..., 0.00365896, 0.00755456,
#         0.00427597],
#        [0.00385307, 0.0093153 , 0.00520914, ..., 0.00541057, 0.01040675,
#         0.00093559]])

# %% [markdown]
# "Uganda": 0,
#     #                                         "Rwanda": 1.4,
#     #                                         "Tanzania": 2.4,
#     #                                         "Kenya": 4

# %%
# def objective(trial):
#     mat = {
#         'iterations': trial.suggest_int('iterations', 1000, 20000),
#         'max_depth': trial.suggest_int('max_depth', 5, 10),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.14),
#         # 'n_estimators': trial.suggest_int('n_estimators', 350, 1000),
#         # 'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
#         'subsample': trial.suggest_float('subsample', 0.85, 1.0),
#         # 'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
#         # 'reg_alpha': trial.suggest_float('reg_alpha', 0.85, 1.0),
#         # 'reg_lambda': trial.suggest_float('reg_lambda', 0.85, 1.0),
#         'random_state': 42
#     }

#     model = catboost.CatBoostRegressor(**mat)

#     scores = cross_val_score(model, train_X, train_y, cv=5, scoring="neg_root_mean_squared_error")

#     return 0 - scores.mean()

# study = optuna.create_study(direction="minimize")
# study.optimize(objective, n_trials=5)

# best_params = study.best_params

# print("Best params:", best_params)

# %%
# cat_features = ["location_type", "age_of_respondent", "gender_of_respondent", "gender_of_respondent", "country"]
feat =  {'iterations': 1500, 'max_depth': 8, 'learning_rate': 0.014239185156809473, 'subsample': 0.9164609728557515}

model = catboost.CatBoostClassifier(
    **feat,
)

model.fit(train_X, train_y)
# Out:
# 0:	learn: 0.6804116	total: 23.1ms	remaining: 34.7s
# 1:	learn: 0.6669459	total: 34.3ms	remaining: 25.7s
# 2:	learn: 0.6539848	total: 44.2ms	remaining: 22.1s
# 3:	learn: 0.6421350	total: 54.1ms	remaining: 20.3s
# 4:	learn: 0.6298957	total: 63.8ms	remaining: 19.1s
# 5:	learn: 0.6182397	total: 73ms	remaining: 18.2s
# 6:	learn: 0.6079744	total: 82.2ms	remaining: 17.5s
# 7:	learn: 0.5969684	total: 92.4ms	remaining: 17.2s
# 8:	learn: 0.5875896	total: 103ms	remaining: 17s
# 9:	learn: 0.5771079	total: 113ms	remaining: 16.9s
# 10:	learn: 0.5683346	total: 123ms	remaining: 16.7s
# 11:	learn: 0.5599190	total: 133ms	remaining: 16.5s
# 12:	learn: 0.5519023	total: 143ms	remaining: 16.4s
# 13:	learn: 0.5439833	total: 153ms	remaining: 16.3s
# 14:	learn: 0.5353522	total: 164ms	remaining: 16.2s
# 15:	learn: 0.5276262	total: 173ms	remaining: 16.1s
# 16:	learn: 0.5206291	total: 183ms	remaining: 16s
# 17:	learn: 0.5130123	total: 193ms	remaining: 15.9s
# 18:	learn: 0.5060732	total: 204ms	remaining: 15.9s
# ...

# %%
# test_data.drop(columns="country", inplace=True)

# test_data = test_data[['cellphone_access', 'gender_of_respondent', 'country_Kenya', 'country_Rwanda', 'country_Tanzania', 'country_Uganda', 'relationship_with_head_Spouse', 'relationship_with_head_Head of Household', 'relationship_with_head_Other relative', 'relationship_with_head_Child', 'relationship_with_head_Parent', 'relationship_with_head_Other non-relatives', 'marital_status_Married/Living together', 'marital_status_Widowed', 'marital_status_Single/Never Married', 'marital_status_Divorced/Seperated', 'marital_status_Dont know', 'education_level_Secondary education', 'education_level_No formal education', 'education_level_Vocational/Specialised training', 'education_level_Primary education', 'education_level_Tertiary education', 'education_level_Other/Dont know/RTA', 'job_type_Self employed', 'job_type_Government Dependent', 'job_type_Formally employed Private', 'job_type_Informally employed', 'job_type_Formally employed Government', 'job_type_Farming and Fishing', 'job_type_Remittance Dependent', 'job_type_Other Income', 'job_type_Dont Know/Refuse to answer', 'job_type_No Income']]

# %%
display(train_X)
display(test_data)
# Out:
# array([[0.01036027, 0.00861177, 0.00481572, ..., 0.00717554, 0.00962079,
#         0.00544548],
#        [0.00357141, 0.00296866, 0.00166008, ..., 0.00128416, 0.00055577,
#         0.00288089],
#        [0.00946271, 0.00786569, 0.00674795, ..., 0.0045686 , 0.02151325,
#         0.00497371],
#        ...,
#        [0.00313799, 0.0075865 , 0.00424239, ..., 0.0032817 , 0.00311176,
#         0.00660709],
#        [0.00279706, 0.00676225, 0.00580131, ..., 0.00365896, 0.00755456,
#         0.00427597],
#        [0.00385307, 0.0093153 , 0.00520914, ..., 0.00541057, 0.01040675,
#         0.00093559]])
# array([[0.00830903, 0.00690671, 0.00592525, ..., 0.00575485, 0.00771596,
#         0.02564432],
#        [0.00486807, 0.00404648, 0.00347147, ..., 0.00337163, 0.01106744,
#         0.0105047 ],
#        [0.00325256, 0.00270363, 0.00151188, ..., 0.00225273, 0.00050615,
#         0.00123271],
#        ...,
#        [0.00220869, 0.0053398 , 0.004581  , ..., 0.0031015 , 0.00596546,
# ...

# %%
pred = model.predict_proba(test_data)

# %%
import matplotlib.pyplot as plt
importances = model.feature_importances_

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(len(importances)), importances)
plt.xticks(range(len(importances)), rotation=90)
plt.xlabel("Features")
plt.ylabel("Importance")
plt.show()

# %%
pred
# Out:
# array([[0.24236133, 0.75763867],
#        [0.11634724, 0.88365276],
#        [0.96694481, 0.03305519],
#        ...,
#        [0.54016854, 0.45983146],
#        [0.96993737, 0.03006263],
#        [0.96107917, 0.03892083]])

# %%
len(pred)
# Out:
# 10086

# %%
f = open("ans5.csv", 'w')

f.write("unique_id,bank_account\n")

# {"Kenya": 3, "Rwanda": 2, "Tanzania": 1, "Uganda": 0}

rev_country_map = {
    3: "Kenya",
    2: "Rwanda",
    1: "Tanzania",
    0: "Uganda"
}


for i in range(len(pred)):
    f.write(str(ids.values[i]) + " x " + countruies.values[i] + "," + str(int(pred[i][1] > 0.51)) + "\n")

f.close()
